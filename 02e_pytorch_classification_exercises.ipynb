# %% [markdown]
# <a href="https://colab.research.google.com/github/mrdbourke/pytorch-deep-learning/blob/main/extras/exercises/02_pytorch_classification_exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 02. PyTorch Classification Exercises
#
# The following is a template for 02. PyTorch Classification exercises.
#
# It's only starter code and it's your job to fill in the blanks.
#
# Because of the flexibility of PyTorch, there may be more than one way to answer the question.
#
# Don't worry about trying to be *right* just try writing code that suffices the question.
#
# ## Resources
# * These exercises are based on [notebook 02 of the learn PyTorch course](https://www.learnpytorch.io/02_pytorch_classification/).
# * You can see one form of [solutions on GitHub](https://github.com/mrdbourke/pytorch-deep-learning/tree/main/extras/solutions) (but try the exercises below yourself first!).

# %%
# Import torch
import torch

# Setup device agnostic code
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print("Device: ", device)

# Setup random seed
RANDOM_SEED = 42
# Out:
# Device:  cuda

# %% [markdown]
# ## 1. Make a binary classification dataset with Scikit-Learn's [`make_moons()`](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_moons.html) function.
#   * For consistency, the dataset should have 1000 samples and a `random_state=42`.
#   * Turn the data into PyTorch tensors.
#   * Split the data into training and test sets using `train_test_split` with 80% training and 20% testing.

# %%
# Create a dataset with Scikit-Learn's make_moons()
from sklearn.datasets import make_moons

X, y = make_moons(
    n_samples=1000,
    noise=0.2,
    random_state=42
)

X.shape, y.shape
# Out:
# ((1000, 2), (1000,))

# %%
# Turn data into a DataFrame
import pandas as pd

x_df = pd.concat([pd.DataFrame(X, columns=["X1", "X2"]), pd.DataFrame(y, columns=['y'])], axis=1)
# x_df = pd.DataFrame(y, columns=['y'])
x_df
# Out:
#            X1        X2  y
# 0   -0.111667  0.520224  1
# 1    1.142650 -0.342577  1
# 2    0.795558 -0.011442  1
# 3    0.111827 -0.551932  1
# 4   -0.816466  0.543996  0
# ..        ...       ... ..
# 995  0.835830  0.435532  0
# 996 -0.195852  0.833794  0
# 997  1.727608 -0.428829  1
# 998 -1.014486  0.135229  0
# 999  0.774381  0.634285  0
#
# [1000 rows x 3 columns]

# %%
# Visualize the data on a scatter plot
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.title('Dataset')
plt.scatter(X[:,0], X[:,1], c=y, )

# %%
# Turn data into tensors of dtype float

# Split the data into train and test sets (80% train, 20% test)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    train_size=0.8,
    random_state=42
)

X_train, X_test= torch.Tensor(X_train).to(device), torch.Tensor(X_test).to(device)
y_train, y_test = torch.Tensor(y_train).to(device), torch.Tensor(y_test).to(device) 

print(len(X_train), len(y_train), len(X_test), len(y_test))
print(X_train[:5], X_test[:5])
print(y_train[:5], y_test[:5])
# Out:
# 800 800 200 200
# tensor([[ 2.1397,  0.3731],
#         [-1.2067,  0.4169],
#         [-0.2117,  1.1715],
#         [-0.0632,  0.9842],
#         [ 0.3938, -0.1620]], device='cuda:0') tensor([[ 0.6248, -0.4549],
#         [ 1.1254,  0.4677],
#         [ 1.3842, -0.3646],
#         [ 0.8931,  0.9734],
#         [ 1.7039, -0.4324]], device='cuda:0')
# tensor([1., 0., 0., 0., 1.], device='cuda:0') tensor([1., 0., 1., 0., 1.], device='cuda:0')

# %% [markdown]
# ## 2. Build a model by subclassing `nn.Module` that incorporates non-linear activation functions and is capable of fitting the data you created in 1.
#   * Feel free to use any combination of PyTorch layers (linear and non-linear) you want.

# %%
import torch
from torch import nn

# Inherit from nn.Module to make a model capable of fitting the mooon data
class MoonModelV0(nn.Module):
    ## Your code here ##
    def __init__(self):
        super().__init__()
        self.layer_1 = nn.Linear(in_features=2, out_features=40)
        self.relu = nn.ReLU()
        self.layer_2 = nn.Linear(in_features=40, out_features=40)
        #self.act2 = nn.ReLU()
        self.layer_3 = nn.Linear(in_features=40, out_features=1)
        #self.act3 = nn.ReLU()
    
    def forward(self, x):
        ## Your code here ##
        # x = self.act1(self.layer_1(x))
        #x = self.act2(self.layer_2(x))
        #x = self.act3(self.layer_3(x))
        return self.layer_3(self.relu(self.layer_2(self.relu(self.layer_1(x)))))

# Instantiate the model
## Your code here ##
model_0 = MoonModelV0().to(device)
model_0
# Out:
# MoonModelV0(
#   (layer_1): Linear(in_features=2, out_features=40, bias=True)
#   (relu): ReLU()
#   (layer_2): Linear(in_features=40, out_features=40, bias=True)
#   (layer_3): Linear(in_features=40, out_features=1, bias=True)
# )

# %% [markdown]
# ## 3. Setup a binary classification compatible loss function and optimizer to use when training the model built in 2.

# %%
# Setup loss function
loss_fn = nn.BCEWithLogitsLoss()
# Setup optimizer to optimize model's parameters
optimizer = torch.optim.SGD(params=model_0.parameters(), lr=0.1)

# %% [markdown]
# ## 4. Create a training and testing loop to fit the model you created in 2 to the data you created in 1.
#   * Do a forward pass of the model to see what's coming out in the form of logits, prediction probabilities and labels.
#   * To measure model accuray, you can create your own accuracy function or use the accuracy function in [TorchMetrics](https://torchmetrics.readthedocs.io/en/latest/).
#   * Train the model for long enough for it to reach over 96% accuracy.
#   * The training loop should output progress every 10 epochs of the model's training and test set loss and accuracy.

# %%
# What's coming out of our model?

# logits (raw outputs of model)
print("Logits:")
## Your code here ##
y_logit = model_0(X_train)
print(y_logit[:5])

# Prediction probabilities
print("Pred probs:")
## Your code here ##
y_pred_prob = torch.sigmoid(y_logit)
print(y_pred_prob[:5])

# Prediction labels
print("Pred labels:")
## Your code here ##
y_pred = torch.round(y_pred_prob)
print(y_pred[:5])
# Out:
# Logits:
# tensor([[-0.1399],
#         [-0.0456],
#         [-0.1039],
#         [-0.0942],
#         [-0.0679]], device='cuda:0', grad_fn=<SliceBackward0>)
# Pred probs:
# tensor([[0.4651],
#         [0.4886],
#         [0.4740],
#         [0.4765],
#         [0.4830]], device='cuda:0', grad_fn=<SliceBackward0>)
# Pred labels:
# tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:0', grad_fn=<SliceBackward0>)

# %%
# Let's calculuate the accuracy using accuracy from TorchMetrics
from torchmetrics import Accuracy

## TODO: Uncomment this code to use the Accuracy function
acc_fn = Accuracy(task="multiclass", num_classes=2).to(device) # send accuracy function to device
acc_fn
# Out:
# MulticlassAccuracy()

# %%
## TODO: Uncomment this to set the seed
torch.manual_seed(RANDOM_SEED)

# Setup epochs
epochs = 2000
training_lost_log = []


# Send data to the device
model_0 = model_0.to(device)

# Loop through the data
for epoch in range(epochs):
  ### Training
  model_0.train()

  # 1. Forward pass (logits output)
  y_logits = model_0(X_train).squeeze()
  # Turn logits into prediction probabilities
  y_pred_prob = torch.sigmoid(y_logits)

  # Turn prediction probabilities into prediction labels
  y_pred = torch.round(y_pred_prob)

  # 2. Calculaute the loss
  loss = loss_fn(y_logits, y_train) # loss = compare model raw outputs to desired model outputs
  training_lost_log.append(loss.cpu())

  # Calculate the accuracy
  acc = acc_fn(y_pred, y_train.int()) # the accuracy function needs to compare pred labels (not logits) with actual labels

  # 3. Zero the gradients
  optimizer.zero_grad()

  # 4. Loss backward (perform backpropagation) - https://brilliant.org/wiki/backpropagation/#:~:text=Backpropagation%2C%20short%20for%20%22backward%20propagation,to%20the%20neural%20network's%20weights.
  loss.backward()
  # 5. Step the optimizer (gradient descent) - https://towardsdatascience.com/gradient-descent-algorithm-a-deep-dive-cf04e8115f21#:~:text=Gradient%20descent%20(GD)%20is%20an,e.g.%20in%20a%20linear%20regression) 
  optimizer.step()

  ### Testing
  model_0.eval() 
  with torch.inference_mode():
    # 1. Forward pass (to get the logits)
    y_logits_eval = model_0(X_test).squeeze(dim=1)
    # Turn the test logits into prediction labels
    y_pred_eval = torch.round(torch.sigmoid(y_logits_eval))

    # 2. Caculate the test loss/acc
    loss_eval = loss_fn(y_logits_eval, y_test)
    acc_eval = acc_fn(y_pred_eval, y_test.int())

  # Print out what's happening every 100 epochs
  if epoch % 100 == 0:
    print(f'Epoch: {epoch} | Training Loss: {loss:.5f} | Traiing Acuracy: {acc*100:.2f}% | Testing Loss: {loss_eval:.2f} | Testing Accuracy: {acc_eval*100:.2f}%')
# Out:
# Epoch: 0 | Training Loss: 0.70161 | Traiing Acuracy: 50.00% | Testing Loss: 0.70 | Testing Accuracy: 50.00%
# Epoch: 100 | Training Loss: 0.31873 | Traiing Acuracy: 85.88% | Testing Loss: 0.32 | Testing Accuracy: 84.00%
# Epoch: 200 | Training Loss: 0.26693 | Traiing Acuracy: 88.12% | Testing Loss: 0.26 | Testing Accuracy: 88.00%
# Epoch: 300 | Training Loss: 0.23324 | Traiing Acuracy: 89.75% | Testing Loss: 0.22 | Testing Accuracy: 90.50%
# Epoch: 400 | Training Loss: 0.19345 | Traiing Acuracy: 92.12% | Testing Loss: 0.18 | Testing Accuracy: 92.00%
# Epoch: 500 | Training Loss: 0.15411 | Traiing Acuracy: 94.25% | Testing Loss: 0.14 | Testing Accuracy: 94.50%
# Epoch: 600 | Training Loss: 0.12376 | Traiing Acuracy: 96.00% | Testing Loss: 0.10 | Testing Accuracy: 97.00%
# Epoch: 700 | Training Loss: 0.10450 | Traiing Acuracy: 96.62% | Testing Loss: 0.08 | Testing Accuracy: 98.00%
# Epoch: 800 | Training Loss: 0.09309 | Traiing Acuracy: 96.62% | Testing Loss: 0.07 | Testing Accuracy: 98.00%
# Epoch: 900 | Training Loss: 0.08612 | Traiing Acuracy: 96.75% | Testing Loss: 0.06 | Testing Accuracy: 98.00%
# Epoch: 1000 | Training Loss: 0.08137 | Traiing Acuracy: 96.88% | Testing Loss: 0.06 | Testing Accuracy: 98.00%
# Epoch: 1100 | Training Loss: 0.07801 | Traiing Acuracy: 96.88% | Testing Loss: 0.06 | Testing Accuracy: 98.00%
# Epoch: 1200 | Training Loss: 0.07556 | Traiing Acuracy: 97.00% | Testing Loss: 0.05 | Testing Accuracy: 98.00%
# Epoch: 1300 | Training Loss: 0.07364 | Traiing Acuracy: 97.00% | Testing Loss: 0.05 | Testing Accuracy: 97.50%
# Epoch: 1400 | Training Loss: 0.07203 | Traiing Acuracy: 97.25% | Testing Loss: 0.05 | Testing Accuracy: 97.50%
# Epoch: 1500 | Training Loss: 0.07052 | Traiing Acuracy: 97.25% | Testing Loss: 0.05 | Testing Accuracy: 97.50%
# Epoch: 1600 | Training Loss: 0.06943 | Traiing Acuracy: 97.38% | Testing Loss: 0.05 | Testing Accuracy: 98.00%
# Epoch: 1700 | Training Loss: 0.06855 | Traiing Acuracy: 97.25% | Testing Loss: 0.05 | Testing Accuracy: 98.50%
# Epoch: 1800 | Training Loss: 0.06774 | Traiing Acuracy: 97.38% | Testing Loss: 0.04 | Testing Accuracy: 98.50%
# Epoch: 1900 | Training Loss: 0.06708 | Traiing Acuracy: 97.25% | Testing Loss: 0.04 | Testing Accuracy: 98.50%

# %% [markdown]
# ## 5. Make predictions with your trained model and plot them using the `plot_decision_boundary()` function created in this notebook.

# %%
# Plot the model predictions
import numpy as np

def plot_decision_boundary(model, X, y):
  
    # Put everything to CPU (works better with NumPy + Matplotlib)
    model.to("cpu")
    X, y = X.to("cpu"), y.to("cpu")

    # Source - https://madewithml.com/courses/foundations/neural-networks/ 
    # (with modifications)
    x_min, x_max = X[:, 0].min() - 0.1, X[:, 0].max() + 0.1
    y_min, y_max = X[:, 1].min() - 0.1, X[:, 1].max() + 0.1
    xx, yy = np.meshgrid(np.linspace(x_min, x_max, 101), 
                         np.linspace(y_min, y_max, 101))

    # Make features
    X_to_pred_on = torch.from_numpy(np.column_stack((xx.ravel(), yy.ravel()))).float()

    # Make predictions
    model.eval()
    with torch.inference_mode():
        y_logits = model(X_to_pred_on)

    # Test for multi-class or binary and adjust logits to prediction labels
    if len(torch.unique(y)) > 2:
        y_pred = torch.softmax(y_logits, dim=1).argmax(dim=1) # mutli-class
    else: 
        y_pred = torch.round(torch.sigmoid(y_logits)) # binary
    
    # Reshape preds and plot
    y_pred = y_pred.reshape(xx.shape).detach().numpy()
    plt.contourf(xx, yy, y_pred, cmap=plt.cm.RdYlBu, alpha=0.7)
    plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.RdYlBu)
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())

# %%
for r in range(len(training_lost_log)):
    training_lost_log[r] = training_lost_log[r].detach().numpy()
print(training_lost_log)
plt.figure(figsize=(12,6))
plt.title("Training Loss Graph")
plt.plot(training_lost_log)
# Out:
# [array(0.7016055, dtype=float32), array(0.6953677, dtype=float32), array(0.6894825, dtype=float32), array(0.68387425, dtype=float32), array(0.6784889, dtype=float32), array(0.6732625, dtype=float32), array(0.6681546, dtype=float32), array(0.6630922, dtype=float32), array(0.6580383, dtype=float32), array(0.65299237, dtype=float32), array(0.6479776, dtype=float32), array(0.64307046, dtype=float32), array(0.6381835, dtype=float32), array(0.6332701, dtype=float32), array(0.6282892, dtype=float32), array(0.6232331, dtype=float32), array(0.6180943, dtype=float32), array(0.6128748, dtype=float32), array(0.60757536, dtype=float32), array(0.60221183, dtype=float32), array(0.5967849, dtype=float32), array(0.5913059, dtype=float32), array(0.58578986, dtype=float32), array(0.58024293, dtype=float32), array(0.57466173, dtype=float32), array(0.56906164, dtype=float32), array(0.5634587, dtype=float32), array(0.55785257, dtype=float32), array(0.5522565, dtype=float32), array(0.5466811, dtype=float32), array(0.5411375, dtype=float32), array(0.53563046, dtype=float32), array(0.5301747, dtype=float32), array(0.52476895, dtype=float32), array(0.5194006, dtype=float32), array(0.5140634, dtype=float32), array(0.5087409, dtype=float32), array(0.50350857, dtype=float32), array(0.49835226, dtype=float32), array(0.49325714, dtype=float32), array(0.48822707, dtype=float32), array(0.48326308, dtype=float32), array(0.47836456, dtype=float32), array(0.47353202, dtype=float32), array(0.46876368, dtype=float32), array(0.46406135, dtype=float32), array(0.459431, dtype=float32), array(0.45487076, dtype=float32), array(0.45038694, dtype=float32), array(0.44597885, dtype=float32), array(0.44164917, dtype=float32), array(0.4373992, dtype=float32), array(0.4332289, dtype=float32), array(0.42913437, dtype=float32), array(0.4251241, dtype=float32), array(0.42119196, dtype=float32), array(0.4173358, dtype=float32), array(0.413564, dtype=float32), array(0.40987793, dtype=float32), array(0.40627515, dtype=float32), array(0.4027574, dtype=float32), array(0.39932373, dtype=float32), array(0.39597532, dtype=float32), array(0.3927094, dtype=float32), array(0.3895246, dtype=float32), array(0.3864211, dtype=float32), array(0.38339567, dtype=float32), array(0.3804501, dtype=float32), array(0.37758484, dtype=float32), array(0.3747994, dtype=float32), array(0.37209365, dtype=float32), array(0.36946517, dtype=float32), array(0.36691004, dtype=float32), array(0.36442718, dtype=float32), array(0.36201644, dtype=float32), array(0.35967788, dtype=float32), array(0.35740775, dtype=float32), array(0.35520554, dtype=float32), array(0.35306877, dtype=float32), array(0.35099465, dtype=float32), array(0.3489801, dtype=float32), array(0.34702522, dtype=float32), array(0.34512818, dtype=float32), array(0.34328273, dtype=float32), array(0.34149012, dtype=float32), array(0.33974892, dtype=float32), array(0.33805645, dtype=float32), array(0.33641228, dtype=float32), array(0.3348159, dtype=float32), array(0.33326682, dtype=float32), array(0.33176062, dtype=float32), array(0.33029595, dtype=float32), array(0.32887027, dtype=float32), array(0.3274829, dtype=float32), array(0.32613334, dtype=float32), array(0.32481888, dtype=float32), array(0.3235368, dtype=float32), array(0.32228768, dtype=float32), array(0.32107124, dtype=float32), array(0.31988564, dtype=float32), array(0.31872755, dtype=float32), array(0.31759542, dtype=float32), array(0.31649214, dtype=float32), array(0.31541604, dtype=float32), array(0.31436798, dtype=float32), array(0.31334576, dtype=float32), array(0.31234744, dtype=float32), array(0.3113727, dtype=float32), array(0.31042084, dtype=float32), array(0.30949065, dtype=float32), array(0.30858287, dtype=float32), array(0.30769545, dtype=float32), array(0.30683136, dtype=float32), array(0.30598706, dtype=float32), array(0.30516142, dtype=float32), array(0.30435362, dtype=float32), array(0.30356377, dtype=float32), array(0.3027909, dtype=float32), array(0.30203584, dtype=float32) ...

# %%
# Plot decision boundaries for training and test sets
plot_decision_boundary(model_0, X_test, y_test)

# %% [markdown]
# ## 6. Replicate the Tanh (hyperbolic tangent) activation function in pure PyTorch.
#   * Feel free to reference the [ML cheatsheet website](https://ml-cheatsheet.readthedocs.io/en/latest/activation_functions.html#tanh) for the formula.

# %%
# Create a straight line tensor
bias = 0.4
weight = 0.9
sample = 1000
start = -100
end = 100
step = 1

X = torch.arange(start=start, end=end, step=step, device=device)
y = weight * X + bias
X[:5], y[:5]
plt.plot(X.cpu())

# %%
# Test torch.tanh() on the tensor and plot it
a = torch.tanh(X)
plt.plot(a.cpu())

# %%
# Replicate torch.tanh() and plot it

# %% [markdown]
# ## 7. Create a multi-class dataset using the [spirals data creation function from CS231n](https://cs231n.github.io/neural-networks-case-study/) (see below for the code).
#   * Split the data into training and test sets (80% train, 20% test) as well as turn it into PyTorch tensors.
#   * Construct a model capable of fitting the data (you may need a combination of linear and non-linear layers).
#   * Build a loss function and optimizer capable of handling multi-class data (optional extension: use the Adam optimizer instead of SGD, you may have to experiment with different values of the learning rate to get it working).
#   * Make a training and testing loop for the multi-class data and train a model on it to reach over 95% testing accuracy (you can use any accuracy measuring function here that you like) - 1000 epochs should be plenty.
#   * Plot the decision boundaries on the spirals dataset from your model predictions, the `plot_decision_boundary()` function should work for this dataset too.

# %%
# Code for creating a spiral dataset from CS231n
import numpy as np
import matplotlib.pyplot as plt
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)
N = 100 # number of points per class
D = 2 # dimensionality
K = 3 # number of classes
X = np.zeros((N*K,D)) # data matrix (each row = single example)
y = np.zeros(N*K, dtype='uint8') # class labels
for j in range(K):
  ix = range(N*j,N*(j+1))
  r = np.linspace(0.0,1,N) # radius
  t = np.linspace(j*4,(j+1)*4,N) + np.random.randn(N)*0.2 # theta
  X[ix] = np.c_[r*np.sin(t), r*np.cos(t)]
  y[ix] = j
# lets visualize the data
plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.RdYlBu)
plt.show()

# %%
# Turn data into tensors
import torch
X = torch.from_numpy(X).type(torch.float) # features as float32
y = torch.from_numpy(y).type(torch.LongTensor) # labels need to be of type long

# Create train and test splits
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=42)
print(len(X_train), len(y_train), len(X_test), len(y_test))
print(X[:5], y[:5])
# Out:
# 240 240 60 60
# tensor([[0.0000, 0.0000],
#         [0.0001, 0.0101],
#         [0.0042, 0.0198],
#         [0.0125, 0.0276],
#         [0.0046, 0.0401]]) tensor([0, 0, 0, 0, 0])

# %%
# Let's calculuate the accuracy for when we fit our model
# !pip -q install torchmetrics # colab doesn't come with torchmetrics
from torchmetrics import Accuracy

## TODO: uncomment the two lines below to send the accuracy function to the device
acc_fn = Accuracy(task="multiclass", num_classes=4).to(device)
acc_fn
# Out:
# ERROR: Invalid requirement: '#'
# MulticlassAccuracy()

# %%
# Prepare device agnostic code
device = "cuda" if torch.cuda.is_available() else "cpu"

# Create model by subclassing nn.Module
class spiralModelV0 (nn.Module):
    def __init__(self):
        super().__init__()
        self.layer_1 = nn.Linear(in_features=2, out_features=8)
        self.layer_2 = nn.Linear(in_features=8, out_features=8)
        self.layer_3 = nn.Linear(in_features=8, out_features=4)
        self.tanh = nn.Tanh()
        
    def forward(self, x):
        return self.layer_3(self.tanh(self.layer_2(self.tanh(self.layer_1(x)))))


# Instantiate model and send it to device
model_1 = spiralModelV0().to(device)
model_1
# Out:
# spiralModelV0(
#   (layer_1): Linear(in_features=2, out_features=8, bias=True)
#   (layer_2): Linear(in_features=8, out_features=8, bias=True)
#   (layer_3): Linear(in_features=8, out_features=4, bias=True)
#   (tanh): Tanh()
# )

# %%
# Setup data to be device agnostic
X_train, y_train = X_train.to(device), y_train.to(device)
X_test, y_test = X_train.to(device), y_train.to(device)

# Print out first 10 untrained model outputs (forward pass)
print("Logits:")
## Your code here ##
y_logits = model_1(X_train)
print(y_logits[:10])

print("Pred probs:")
## Your code here ##
y_pred_probs = torch.softmax(y_logits, dim=1)
print(y_pred_prob[:10])

print("Pred labels:")
## Your code here ##
y_label = torch.sum(y_pred_probs[0])
print(y_label)
# Out:
# Logits:
# tensor([[ 0.2117, -0.1256,  0.2182,  0.0210],
#         [ 0.1651, -0.1074,  0.1656, -0.0344],
#         [ 0.1956, -0.1570,  0.1934,  0.0319],
#         [ 0.0688, -0.1556,  0.0336, -0.0812],
#         [ 0.1131, -0.1792,  0.0827, -0.0202],
#         [ 0.1507, -0.1578,  0.1375, -0.0049],
#         [ 0.1670, -0.1599,  0.1574,  0.0104],
#         [ 0.3219, -0.1448,  0.3459,  0.1247],
#         [ 0.1233, -0.1240,  0.1117, -0.0580],
#         [ 0.0679, -0.1561,  0.0323, -0.0817]], device='cuda:0',
#        grad_fn=<SliceBackward0>)
# Pred probs:
# tensor([9.9999e-01, 6.0952e-06, 4.9921e-05, 1.1704e-03, 9.9514e-01, 1.2390e-02,
#         9.1741e-01, 9.9896e-01, 4.9675e-04, 2.5094e-03], device='cuda:0',
#        grad_fn=<SliceBackward0>)
# Pred labels:
# tensor(1., device='cuda:0', grad_fn=<SumBackward0>)

# %%
# Setup loss function and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(params=model_1.parameters(), lr=0.1)

# %%
# Build a training loop for the model

# Loop over data
epochs = 1000

for epoch in range(epochs):
  ## Training
  model_1.train()

  # 1. Forward pass
  y_logits = model_1(X_train)
  y_preds = torch.softmax(y_logits, dim=1).argmax(dim=1)

  # 2. Calculate the loss
  loss = loss_fn(y_logits, y_train.type(torch.long))
  acc = acc_fn(y_train, y_preds)
  
  # 3. Optimizer zero grad
  optimizer.zero_grad()

  # 4. Loss backward
  loss.backward()

  # 5. Optimizer step
  optimizer.step()

  ## Testing
  model_1.eval()
  with torch.inference_mode():
    # 1. Forward pass
    y_logits_eval = model_1(X_test)
    y_preds_eval = torch.softmax(y_logits_eval, dim=1).argmax(dim=1)
    
    # 2. Caculate loss and acc
    loss_eval = loss_fn(y_logits_eval, y_test.type(torch.long))
    acc_eval = acc_fn(y_test, y_preds_eval)
    
  # Print out what's happening every 100 epochs
  if epoch % 10 == 0:
    print(f'Epoch: {epoch} | Training Loss: {loss} | Training Accuracy: {acc} | Testing Loss: {loss_eval} | Testing Accuracy: {acc_eval}')
# Out:
# Epoch: 0 | Training Loss: 1.36356782913208 | Training Accuracy: 0.4749999940395355 | Testing Loss: 1.3472082614898682 | Testing Accuracy: 0.4583333432674408
# Epoch: 10 | Training Loss: 1.2423444986343384 | Training Accuracy: 0.5208333134651184 | Testing Loss: 1.2339682579040527 | Testing Accuracy: 0.4833333194255829
# Epoch: 20 | Training Loss: 1.1752855777740479 | Training Accuracy: 0.5541666746139526 | Testing Loss: 1.1701185703277588 | Testing Accuracy: 0.5708333253860474
# Epoch: 30 | Training Loss: 1.1306194067001343 | Training Accuracy: 0.5666666626930237 | Testing Loss: 1.1267954111099243 | Testing Accuracy: 0.5666666626930237
# Epoch: 40 | Training Loss: 1.0952873229980469 | Training Accuracy: 0.574999988079071 | Testing Loss: 1.0920201539993286 | Testing Accuracy: 0.574999988079071
# Epoch: 50 | Training Loss: 1.06380033493042 | Training Accuracy: 0.5791666507720947 | Testing Loss: 1.0607582330703735 | Testing Accuracy: 0.5833333134651184
# Epoch: 60 | Training Loss: 1.0338479280471802 | Training Accuracy: 0.5708333253860474 | Testing Loss: 1.0308964252471924 | Testing Accuracy: 0.5666666626930237
# Epoch: 70 | Training Loss: 1.0045868158340454 | Training Accuracy: 0.5708333253860474 | Testing Loss: 1.001691460609436 | Testing Accuracy: 0.5708333253860474
# Epoch: 80 | Training Loss: 0.9759367108345032 | Training Accuracy: 0.5416666865348816 | Testing Loss: 0.9731144309043884 | Testing Accuracy: 0.5416666865348816
# Epoch: 90 | Training Loss: 0.9481794238090515 | Training Accuracy: 0.5291666388511658 | Testing Loss: 0.9454680681228638 | Testing Accuracy: 0.5291666388511658
# Epoch: 100 | Training Loss: 0.921721339225769 | Training Accuracy: 0.5375000238418579 | Testing Loss: 0.9191634058952332 | Testing Accuracy: 0.5416666865348816
# Epoch: 110 | Training Loss: 0.8969898223876953 | Training Accuracy: 0.5458333492279053 | Testing Loss: 0.8946275115013123 | Testing Accuracy: 0.5416666865348816
# Epoch: 120 | Training Loss: 0.8743866086006165 | Training Accuracy: 0.5375000238418579 | Testing Loss: 0.8722569346427917 | Testing Accuracy: 0.5333333611488342
# Epoch: 130 | Training Loss: 0.8542349934577942 | Training Accuracy: 0.5375000238418579 | Testing Loss: 0.8523629307746887 | Testing Accuracy: 0.5333333611488342
# Epoch: 140 | Training Loss: 0.8367121815681458 | Training Accuracy: 0.5333333611488342 | Testing Loss: 0.835105836391449 | Testing Accuracy: 0.5333333611488342
# Epoch: 150 | Training Loss: 0.8218143582344055 | Training Accuracy: 0.5375000238418579 | Testing Loss: 0.8204634189605713 | Testing Accuracy: 0.5375000238418579
# Epoch: 160 | Training Loss: 0.8093674778938293 | Training Accuracy: 0.5291666388511658 | Testing Loss: 0.8082472085952759 | Testing Accuracy: 0.5249999761581421
# Epoch: 170 | Training Loss: 0.7990788817405701 | Training Accuracy: 0.5208333134651184 | Testing Loss: 0.7981553673744202 | Testing Accuracy: 0.5208333134651184
# Epoch: 180 | Training Loss: 0.7905999422073364 | Training Accuracy: 0.5291666388511658 | Testing Loss: 0.7898380160331726 | Testing Accuracy: 0.5291666388511658
# Epoch: 190 | Training Loss: 0.7835816144943237 | Training Accuracy: 0.5249999761581421 | Testing Loss: 0.782947301864624 | Testing Accuracy: 0.5249999761581421
# Epoch: 200 | Training Loss: 0.7777073383331299 | Training Accuracy: 0.5208333134651184 | Testing Loss: 0.7771721482276917 | Testing Accuracy: 0.5208333134651184
# Epoch: 210 | Training Loss: 0.7727108001708984 | Training Accuracy: 0.5208333134651184 | Testing Loss: 0.7722508907318115 | Testing Accuracy: 0.5208333134651184
# Epoch: 220 | Training Loss: 0.7683779001235962 | Training Accuracy: 0.5208333134651184 | Testing Loss: 0.7679744958877563 | Testing Accuracy: 0.5208333134651184
# Epoch: 230 | Training Loss: 0.7645425200462341 | Training Accuracy: 0.5208333134651184 | Testing Loss: 0.7641811966896057 | Testing Accuracy: 0.5208333134651184
# Epoch: 240 | Training Loss: 0.7610787749290466 | Training Accuracy: 0.5291666388511658 | Testing Loss: 0.7607488632202148 | Testing Accuracy: 0.5291666388511658
# Epoch: 250 | Training Loss: 0.7578921914100647 | Training Accuracy: 0.5291666388511658 | Testing Loss: 0.7575858235359192 | Testing Accuracy: 0.5291666388511658
# Epoch: 260 | Training Loss: 0.7549132108688354 | Training Accuracy: 0.5291666388511658 | Testing Loss: 0.754624605178833 | Testing Accuracy: 0.5291666388511658
# Epoch: 270 | Training Loss: 0.7520908117294312 | Training Accuracy: 0.5249999761581421 | Testing Loss: 0.7518155574798584 | Testing Accuracy: 0.5249999761581421
# Epoch: 280 | Training Loss: 0.749386727809906 | Training Accuracy: 0.5249999761581421 | Testing Loss: 0.7491215467453003 | Testing Accuracy: 0.5249999761581421
# Epoch: 290 | Training Loss: 0.7467729449272156 | Training Accuracy: 0.5249999761581421 | Testing Loss: 0.7465156316757202 | Testing Accuracy: 0.5249999761581421
# Epoch: 300 | Training Loss: 0.7442284226417542 | Training Accuracy: 0.5291666388511658 | Testing Loss: 0.743976891040802 | Testing Accuracy: 0.5291666388511658
# Epoch: 310 | Training Loss: 0.7417365908622742 | Training Accuracy: 0.5249999761581421 | Testing Loss: 0.7414897680282593 | Testing Accuracy: 0.5249999761581421
# Epoch: 320 | Training Loss: 0.7392852902412415 | Training Accuracy: 0.5249999761581421 | Testing Loss: 0.7390420436859131 | Testing Accuracy: 0.5249999761581421
# Epoch: 330 | Training Loss: 0.7368642091751099 | Training Accuracy: 0.5249999761581421 | Testing Loss: 0.7366234660148621 | Testing Accuracy: 0.5249999761581421
# Epoch: 340 | Training Loss: 0.7344652414321899 | Training Accuracy: 0.5291666388511658 | Testing Loss: 0.7342261672019958 | Testing Accuracy: 0.5291666388511658
# Epoch: 350 | Training Loss: 0.7320809960365295 | Training Accuracy: 0.5291666388511658 | Testing Loss: 0.731843113899231 | Testing Accuracy: 0.5291666388511658
# Epoch: 360 | Training Loss: 0.729705810546875 | Training Accuracy: 0.5291666388511658 | Testing Loss: 0.7294684648513794 | Testing Accuracy: 0.5291666388511658
# Epoch: 370 | Training Loss: 0.7273337244987488 | Training Accuracy: 0.5291666388511658 | Testing Loss: 0.7270963788032532 | Testing Accuracy: 0.5291666388511658
# Epoch: 380 | Training Loss: 0.7249595522880554 | Training Accuracy: 0.5291666388511658 | Testing Loss: 0.7247218489646912 | Testing Accuracy: 0.5291666388511658
# Epoch: 390 | Training Loss: 0.7225788831710815 | Training Accuracy: 0.5291666388511658 | Testing Loss: 0.7223401665687561 | Testing Accuracy: 0.5291666388511658
# Epoch: 400 | Training Loss: 0.7201864719390869 | Training Accuracy: 0.5291666388511658 | Testing Loss: 0.7199463248252869 | Testing Accuracy: 0.5291666388511658
# Epoch: 410 | Training Loss: 0.717777669429779 | Training Accuracy: 0.5291666388511658 | Testing Loss: 0.7175357341766357 | Testing Accuracy: 0.5291666388511658
# Epoch: 420 | Training Loss: 0.7153481841087341 | Training Accuracy: 0.5333333611488342 | Testing Loss: 0.7151038646697998 | Testing Accuracy: 0.5333333611488342
# Epoch: 430 | Training Loss: 0.7128930687904358 | Training Accuracy: 0.5333333611488342 | Testing Loss: 0.712645947933197 | Testing Accuracy: 0.5333333611488342
# Epoch: 440 | Training Loss: 0.7104077935218811 | Training Accuracy: 0.5333333611488342 | Testing Loss: 0.7101572751998901 | Testing Accuracy: 0.5333333611488342
# Epoch: 450 | Training Loss: 0.7078874111175537 | Training Accuracy: 0.5333333611488342 | Testing Loss: 0.7076330780982971 | Testing Accuracy: 0.5333333611488342
# Epoch: 460 | Training Loss: 0.7053269147872925 | Training Accuracy: 0.5375000238418579 | Testing Loss: 0.7050684690475464 | Testing Accuracy: 0.5375000238418579
# Epoch: 470 | Training Loss: 0.7027215361595154 | Training Accuracy: 0.5416666865348816 | Testing Loss: 0.7024583220481873 | Testing Accuracy: 0.5416666865348816
# Epoch: 480 | Training Loss: 0.7000660300254822 | Training Accuracy: 0.5458333492279053 | Testing Loss: 0.699797511100769 | Testing Accuracy: 0.5458333492279053
# Epoch: 490 | Training Loss: 0.6973549723625183 | Training Accuracy: 0.5416666865348816 | Testing Loss: 0.6970804333686829 | Testing Accuracy: 0.5416666865348816
# Epoch: 500 | Training Loss: 0.6945828199386597 | Training Accuracy: 0.550000011920929 | Testing Loss: 0.6943018436431885 | Testing Accuracy: 0.550000011920929
# Epoch: 510 | Training Loss: 0.6917438507080078 | Training Accuracy: 0.5541666746139526 | Testing Loss: 0.6914559006690979 | Testing Accuracy: 0.5541666746139526
# Epoch: 520 | Training Loss: 0.68883216381073 | Training Accuracy: 0.5583333373069763 | Testing Loss: 0.6885366439819336 | Testing Accuracy: 0.5583333373069763
# Epoch: 530 | Training Loss: 0.6858416199684143 | Training Accuracy: 0.5583333373069763 | Testing Loss: 0.6855378746986389 | Testing Accuracy: 0.5583333373069763
# Epoch: 540 | Training Loss: 0.6827656626701355 | Training Accuracy: 0.5625 | Testing Loss: 0.6824529767036438 | Testing Accuracy: 0.5625
# Epoch: 550 | Training Loss: 0.6795976161956787 | Training Accuracy: 0.5625 | Testing Loss: 0.6792755722999573 | Testing Accuracy: 0.5625
# Epoch: 560 | Training Loss: 0.6763306856155396 | Training Accuracy: 0.5625 | Testing Loss: 0.6759981513023376 | Testing Accuracy: 0.5625
# Epoch: 570 | Training Loss: 0.6729575395584106 | Training Accuracy: 0.5625 | Testing Loss: 0.6726140379905701 | Testing Accuracy: 0.5625
# Epoch: 580 | Training Loss: 0.6694706678390503 | Training Accuracy: 0.5625 | Testing Loss: 0.6691154837608337 | Testing Accuracy: 0.5625
# Epoch: 590 | Training Loss: 0.6658623218536377 | Training Accuracy: 0.5625 | Testing Loss: 0.6654946804046631 | Testing Accuracy: 0.5625
# Epoch: 600 | Training Loss: 0.6621248722076416 | Training Accuracy: 0.5583333373069763 | Testing Loss: 0.6617438793182373 | Testing Accuracy: 0.5583333373069763
# Epoch: 610 | Training Loss: 0.6582502126693726 | Training Accuracy: 0.5625 | Testing Loss: 0.6578549146652222 | Testing Accuracy: 0.5625
# Epoch: 620 | Training Loss: 0.6542302966117859 | Training Accuracy: 0.5625 | Testing Loss: 0.6538200974464417 | Testing Accuracy: 0.5625
# Epoch: 630 | Training Loss: 0.6500570774078369 | Training Accuracy: 0.5666666626930237 | Testing Loss: 0.6496310830116272 | Testing Accuracy: 0.5666666626930237
# Epoch: 640 | Training Loss: 0.6457226872444153 | Training Accuracy: 0.574999988079071 | Testing Loss: 0.6452800631523132 | Testing Accuracy: 0.574999988079071
# Epoch: 650 | Training Loss: 0.6412194967269897 | Training Accuracy: 0.5833333134651184 | Testing Loss: 0.6407595872879028 | Testing Accuracy: 0.5833333134651184
# Epoch: 660 | Training Loss: 0.6365400552749634 | Training Accuracy: 0.5833333134651184 | Testing Loss: 0.63606196641922 | Testing Accuracy: 0.5833333134651184
# Epoch: 670 | Training Loss: 0.6316772699356079 | Training Accuracy: 0.5916666388511658 | Testing Loss: 0.6311805248260498 | Testing Accuracy: 0.5916666388511658
# Epoch: 680 | Training Loss: 0.6266246438026428 | Training Accuracy: 0.5958333611488342 | Testing Loss: 0.6261087656021118 | Testing Accuracy: 0.5958333611488342
# Epoch: 690 | Training Loss: 0.6213764548301697 | Training Accuracy: 0.6000000238418579 | Testing Loss: 0.6208407282829285 | Testing Accuracy: 0.6000000238418579
# Epoch: 700 | Training Loss: 0.61592698097229 | Training Accuracy: 0.6041666865348816 | Testing Loss: 0.6153708100318909 | Testing Accuracy: 0.6083333492279053
# Epoch: 710 | Training Loss: 0.6102715134620667 | Training Accuracy: 0.6083333492279053 | Testing Loss: 0.6096944212913513 | Testing Accuracy: 0.6083333492279053
# Epoch: 720 | Training Loss: 0.604405403137207 | Training Accuracy: 0.6083333492279053 | Testing Loss: 0.6038070321083069 | Testing Accuracy: 0.6083333492279053
# Epoch: 730 | Training Loss: 0.5983242392539978 | Training Accuracy: 0.612500011920929 | Testing Loss: 0.5977042317390442 | Testing Accuracy: 0.612500011920929
# Epoch: 740 | Training Loss: 0.5920243859291077 | Training Accuracy: 0.6166666746139526 | Testing Loss: 0.5913821458816528 | Testing Accuracy: 0.6166666746139526
# Epoch: 750 | Training Loss: 0.5855017304420471 | Training Accuracy: 0.6166666746139526 | Testing Loss: 0.5848369598388672 | Testing Accuracy: 0.6166666746139526
# Epoch: 760 | Training Loss: 0.578752338886261 | Training Accuracy: 0.625 | Testing Loss: 0.5780648589134216 | Testing Accuracy: 0.625
# Epoch: 770 | Training Loss: 0.5717723369598389 | Training Accuracy: 0.6291666626930237 | Testing Loss: 0.5710614323616028 | Testing Accuracy: 0.6291666626930237
# Epoch: 780 | Training Loss: 0.564557671546936 | Training Accuracy: 0.6416666507720947 | Testing Loss: 0.5638230443000793 | Testing Accuracy: 0.6416666507720947
# Epoch: 790 | Training Loss: 0.5571047067642212 | Training Accuracy: 0.6458333134651184 | Testing Loss: 0.5563462376594543 | Testing Accuracy: 0.6458333134651184
# Epoch: 800 | Training Loss: 0.5494109392166138 | Training Accuracy: 0.6541666388511658 | Testing Loss: 0.5486282110214233 | Testing Accuracy: 0.6541666388511658
# Epoch: 810 | Training Loss: 0.5414754748344421 | Training Accuracy: 0.675000011920929 | Testing Loss: 0.5406686663627625 | Testing Accuracy: 0.675000011920929
# Epoch: 820 | Training Loss: 0.5333004593849182 | Training Accuracy: 0.6875 | Testing Loss: 0.5324699878692627 | Testing Accuracy: 0.6875
# Epoch: 830 | Training Loss: 0.5248926877975464 | Training Accuracy: 0.6958333253860474 | Testing Loss: 0.524039626121521 | Testing Accuracy: 0.699999988079071
# Epoch: 840 | Training Loss: 0.5162647366523743 | Training Accuracy: 0.7083333134651184 | Testing Loss: 0.5153905153274536 | Testing Accuracy: 0.7083333134651184
# Epoch: 850 | Training Loss: 0.507436215877533 | Training Accuracy: 0.7166666388511658 | Testing Loss: 0.5065434575080872 | Testing Accuracy: 0.7166666388511658
# Epoch: 860 | Training Loss: 0.49843496084213257 | Training Accuracy: 0.7250000238418579 | Testing Loss: 0.497526615858078 | Testing Accuracy: 0.7291666865348816
# Epoch: 870 | Training Loss: 0.4892960786819458 | Training Accuracy: 0.7416666746139526 | Testing Loss: 0.4883762300014496 | Testing Accuracy: 0.7416666746139526
# Epoch: 880 | Training Loss: 0.48006126284599304 | Training Accuracy: 0.7458333373069763 | Testing Loss: 0.4791342616081238 | Testing Accuracy: 0.7458333373069763
# Epoch: 890 | Training Loss: 0.47077640891075134 | Training Accuracy: 0.7583333253860474 | Testing Loss: 0.4698469340801239 | Testing Accuracy: 0.7583333253860474
# Epoch: 900 | Training Loss: 0.46148917078971863 | Training Accuracy: 0.762499988079071 | Testing Loss: 0.46056216955184937 | Testing Accuracy: 0.7666666507720947
# Epoch: 910 | Training Loss: 0.45224615931510925 | Training Accuracy: 0.7791666388511658 | Testing Loss: 0.4513261020183563 | Testing Accuracy: 0.7791666388511658
# Epoch: 920 | Training Loss: 0.4430907070636749 | Training Accuracy: 0.7791666388511658 | Testing Loss: 0.44218140840530396 | Testing Accuracy: 0.7791666388511658
# Epoch: 930 | Training Loss: 0.43406036496162415 | Training Accuracy: 0.800000011920929 | Testing Loss: 0.43316546082496643 | Testing Accuracy: 0.8041666746139526
# Epoch: 940 | Training Loss: 0.4251868426799774 | Training Accuracy: 0.8083333373069763 | Testing Loss: 0.4243091940879822 | Testing Accuracy: 0.8083333373069763
# Epoch: 950 | Training Loss: 0.41649532318115234 | Training Accuracy: 0.8125 | Testing Loss: 0.41563698649406433 | Testing Accuracy: 0.8125
# Epoch: 960 | Training Loss: 0.408004492521286 | Training Accuracy: 0.824999988079071 | Testing Loss: 0.40716707706451416 | Testing Accuracy: 0.824999988079071
# Epoch: 970 | Training Loss: 0.39972764253616333 | Training Accuracy: 0.824999988079071 | Testing Loss: 0.3989119529724121 | Testing Accuracy: 0.824999988079071
# Epoch: 980 | Training Loss: 0.39167293906211853 | Training Accuracy: 0.8374999761581421 | Testing Loss: 0.39087989926338196 | Testing Accuracy: 0.8374999761581421
# Epoch: 990 | Training Loss: 0.38384494185447693 | Training Accuracy: 0.8416666388511658 | Testing Loss: 0.38307470083236694 | Testing Accuracy: 0.8416666388511658

# %%
# Plot decision boundaries for training and test sets
plot_decision_boundary(model_1, X_test, y_test)
